# %%
from PIL import Image
import numpy as np

# %%
img = Image.open("Path no Labels.jpg").convert("L")
img_arr = np.array(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> img = Image.open("Path no Labels.jpg").convert("L")
#       <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> img_arr = np.array(img)
#
# File /opt/homebrew/lib/python3.11/site-packages/PIL/Image.py:3131, in open(fp, mode, formats)
#    3128     filename = fp
#    3130 if filename:
# -> 3131     fp = builtins.open(filename, "rb")
#    3132     exclusive_fp = True
#    3134 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Path no Labels.jpg'

# %%
for row in range(len(img_arr)):
    for col in range(len(img_arr[row])):
        if img_arr[row][col] > 100:
            img_arr[row][col] = 255
        else:
            img_arr[row][col] = 0

# %%
img = Image.open("output.jpg").convert("L")
img_arr = np.array(img)

# %%
ref_img = []
counter = 0
for row in range(len(img_arr)):
    for ele in range(len(img_arr[0])):
        if img_arr[row][ele] > 200:
            img_arr[row][ele] = 255
        elif img_arr[row][ele] < 50:
            img_arr[row][ele] = 0
        else:
            img_arr[row][ele] = 100
            ref_img.append([row, ele])
# Out:
# [[209, 724], [444, 315]]

# %%
ref_coo = [[43.471806, -80.547952], [43.471175, -80.549465]]
my = (ref_coo[0][0] - ref_coo[1][0]) / (ref_img[0][0] - ref_img[1][0])
mx = (ref_coo[0][1] - ref_coo[1][1]) / (ref_img[0][1] - ref_img[1][1])

y_coo = lambda img_y : ref_coo[0][0] + (my * (img_y - ref_img[0][0]))
x_coo = lambda img_x : ref_coo[0][1] + (mx * (img_x - ref_img[0][1]))

# %%
tree = {}
for col in range(len(img_arr)):
    for row in range(len(img_arr[0])):
        if img_arr[col][row] != 255:
            neighbours = []
            for num1 in [-1, 0, 1]:
                for num2 in [-1, 0, 1]:
                    try:
                        if img_arr[col + num1][row + num2] != 255 and num1 + num2 != 0:
                            neighbours.append("(" + str(col + num1) + ", " + str(row + num2) + ")")
                    except:
                        pass
            tree["(" + str(col) + ", " + str(row) + ")"] = (neighbours, (y_coo(col), x_coo(row)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> tree = {}
# ----> <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> for col in range(len(img_arr)):
#       <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     for row in range(len(img_arr[0])):
#       <a href='vscode-notebook-cell:/Users/elijah/Downloads/CodingPractice/sedesignproject/self-driving-tank/path_extraction.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>         if img_arr[col][row] != 255:
#
# NameError: name 'img_arr' is not defined

# %%
import cv2

# Open the video capture device
cap = cv2.VideoCapture(0)  # Use '0' for the default camera, or change to another index for a different device
ret, image = cap.read()
image.shape
# Out:
# (1080, 1920, 3)

# %%
# Out:
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
